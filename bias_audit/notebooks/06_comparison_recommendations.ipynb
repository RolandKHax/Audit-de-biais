# %% [markdown]
# # 06 - Comparaison et recommandations
#
# Synthèse finale : compromis performance/fairness, limites et recommandations opérationnelles.

# %%
import json
from pathlib import Path
import pandas as pd
metrics_path = Path('../results/metrics/audit_metrics.json')
data = json.loads(metrics_path.read_text(encoding='utf-8'))
display(pd.DataFrame(data['baseline_evaluation']['aggregate_summary']))
display(pd.DataFrame(data['recommendations']))
