# %% [markdown]
# # 04 - Mitigation reweighting/resampling
#
# Analyse des méthodes de pré-processing par pondération et ré-échantillonnage.

# %%
import pandas as pd
from pathlib import Path
path = Path('../results/tables/mitigation_summary.csv')
if not path.exists():
    raise FileNotFoundError('Lancez scripts/run_all.sh avant ce notebook.')
df = pd.read_csv(path)
df[df['method'].isin(['reweighting', 'resampling'])]
