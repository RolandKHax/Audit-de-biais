# %% [markdown]
# # 05 - Adversarial debiasing PyTorch
#
# Comparaison des valeurs de λ pour apprendre une représentation moins informative sur l'attribut sensible.

# %%
import pandas as pd
from pathlib import Path
path = Path('../results/tables/mitigation_summary.csv')
if not path.exists():
    raise FileNotFoundError('Lancez scripts/train_adversarial.py ou scripts/run_all.sh avant ce notebook.')
df = pd.read_csv(path)
df[df['method'].eq('adversarial_pytorch')]
